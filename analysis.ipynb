# %% [markdown]
# ## TDDPG

# %%
import matplotlib.pyplot as plt

# Data for each attribute for each epoch
epochs = ['Epoch 0', 'Epoch 1', 'Epoch 2']
hit_rate = [0.9835082458770614, 0.9820089955022488, 0.9810094952523738]
ndcg = [0.9103298809379037, 0.9088363409740189, 0.9096243969097395]
precision = [0.23148425787106444, 0.23163418290854573, 0.2312843578210895]
recall = [0.9734854184629297, 0.972819084963013, 0.9716383261360773]
f1 = [0.37402827150414786, 0.37417469450533986, 0.37363092819900434]

# Labels for x-axis
labels = [epoch for epoch in epochs]

# Width of each bar
bar_width = 0.15
index = range(len(epochs))

# Plotting the grouped bar chart
plt.figure(figsize=(10, 6))
plt.bar(index, hit_rate, bar_width, label='Top 5 Hit Rate')
plt.bar([i + bar_width for i in index], ndcg, bar_width, label='nDCG')
plt.bar([i + 2*bar_width for i in index], precision, bar_width, label='Precision')
plt.bar([i + 3*bar_width for i in index], recall, bar_width, label='Recall')
plt.bar([i + 4*bar_width for i in index], f1, bar_width, label='F1')

# Add labels, title, and legend
plt.xlabel('Epochs')
plt.ylabel('Scores')
# plt.title('Cluster 0 Evaluation Metrics')
plt.xticks([i + 2*bar_width for i in index], labels, rotation=45, ha='right')
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for each attribute for each epoch
epochs = ['Top 5 vs. Top 10', 'Top 10 vs. Top 20']
hit_rate = [0.9835082458770614, 0.9910044977511244, 0.9955022488755623]
ndcg = [0.9103298809379037, 0.9116369515874008, 0.9125927443736516]
precision = [0.23148425787106444, 0.1209895052473763, 0.06124437781109446]
recall = [0.9734854184629297, 0.9896626778185997, 0.9955022488755623]
f1 = [0.37402827150414786, 0.2156187000167326, 0.11538973791328405]

# Calculate differences for each metric
hit_rate_diff = np.diff(hit_rate)
ndcg_diff = np.diff(ndcg)
precision_diff = np.diff(precision)
recall_diff = np.diff(recall)
f1_diff = np.diff(f1)

# Labels for x-axis
labels = [epoch for epoch in epochs]  # Exclude the first epoch for differences

# Create the diverging bar chart
fig, ax = plt.subplots(figsize=(10, 6))

# Plotting the bars
bar_width = 0.15
index = np.arange(len(labels))
opacity = 0.7

bar1 = ax.bar(index, hit_rate_diff, bar_width, alpha=opacity, color='b', label='Hit Rate')
bar2 = ax.bar(index + bar_width, ndcg_diff, bar_width, alpha=opacity, color='g', label='nDCG')
bar3 = ax.bar(index + 2*bar_width, precision_diff, bar_width, alpha=opacity, color='r', label='Precision')
bar4 = ax.bar(index + 3*bar_width, recall_diff, bar_width, alpha=opacity, color='c', label='Recall')
bar5 = ax.bar(index + 4*bar_width, f1_diff, bar_width, alpha=opacity, color='m', label='F1')

# Add labels, title, and legend
ax.set_xlabel('Epochs')
ax.set_ylabel('Changes')
# ax.set_title('Changes in Cluster 0 Evaluation Metrics in Top 5 vs. Top 10 vs. Top 20')
ax.set_xticks(index + 2*bar_width)
ax.set_xticklabels(labels, rotation=45, ha='right')
ax.legend()

# Adding horizontal line at 0
ax.axhline(0, color='gray', linewidth=0.8)

# Adding labels for the changes
for rects in [bar1, bar2, bar3, bar4, bar5]:
    for rect in rects:
        height = rect.get_height()
        if height > 0:
            ax.text(rect.get_x() + rect.get_width() / 2., height,
                    '%.3f' % height,
                    ha='center', va='bottom')
        else:
            ax.text(rect.get_x() + rect.get_width() / 2., height,
                    '%.3f' % height,
                    ha='center', va='top')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## TDQN

# %%
import matplotlib.pyplot as plt

# Data for each attribute for each epoch
epochs = ['Epoch 0', 'Epoch 1', 'Epoch 2']
hit_rate = [0.9730134932533733, 0.974512743628186, 0.9750124937531235]
ndcg = [0.8471671636831104, 0.8610479868030371, 0.8822098621084726]
precision = [0.22938530734632684, 0.22983508245877063, 0.230784607696151945]
recall = [0.9632905159142041, 0.9645648787327946, 0.9659304657805408]
f1 = [0.3705357339848524, 0.3712167951024109, 0.3725560114844819]

# Labels for x-axis
labels = [epoch for epoch in epochs]

# Width of each bar
bar_width = 0.15
index = range(len(epochs))

# Plotting the grouped bar chart
plt.figure(figsize=(10, 6))
plt.bar(index, hit_rate, bar_width, label='Top 5 Hit Rate')
plt.bar([i + bar_width for i in index], ndcg, bar_width, label='nDCG')
plt.bar([i + 2*bar_width for i in index], precision, bar_width, label='Precision')
plt.bar([i + 3*bar_width for i in index], recall, bar_width, label='Recall')
plt.bar([i + 4*bar_width for i in index], f1, bar_width, label='F1')

# Add labels, title, and legend
plt.xlabel('Epochs')
plt.ylabel('Scores')
# plt.title('Cluster 0 Evaluation Metrics')
plt.xticks([i + 2*bar_width for i in index], labels, rotation=45, ha='right')
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for each attribute for each epoch
epochs = ['Top 5 vs. Top 10', 'Top 10 vs. Top 20']
hit_rate = [0.9730134932533733, 0.974512743628186, 0.9820089955022488]
ndcg = [0.8471671636831104, 0.8473045151081376, 0.8488835281452239]
precision = [0.22938530734632684, 0.1184407796101949, 0.060269865067466274]
recall = [0.9632905159142041, 0.9702081193835316, 0.9797958163775256]
f1 = [0.3705357339848524, 0.21110957002824055, 0.11355456856804359]

# Calculate differences for each metric
hit_rate_diff = np.diff(hit_rate)
ndcg_diff = np.diff(ndcg)
precision_diff = np.diff(precision)
recall_diff = np.diff(recall)
f1_diff = np.diff(f1)

# Labels for x-axis
labels = [epoch for epoch in epochs]  # Exclude the first epoch for differences

# Create the diverging bar chart
fig, ax = plt.subplots(figsize=(10, 6))

# Plotting the bars
bar_width = 0.15
index = np.arange(len(labels))
opacity = 0.7

bar1 = ax.bar(index, hit_rate_diff, bar_width, alpha=opacity, color='b', label='Hit Rate')
bar2 = ax.bar(index + bar_width, ndcg_diff, bar_width, alpha=opacity, color='g', label='nDCG')
bar3 = ax.bar(index + 2*bar_width, precision_diff, bar_width, alpha=opacity, color='r', label='Precision')
bar4 = ax.bar(index + 3*bar_width, recall_diff, bar_width, alpha=opacity, color='c', label='Recall')
bar5 = ax.bar(index + 4*bar_width, f1_diff, bar_width, alpha=opacity, color='m', label='F1')

# Add labels, title, and legend
ax.set_xlabel('Epochs')
ax.set_ylabel('Changes')
# ax.set_title('Changes in Cluster 0 Evaluation Metrics in Top 5 vs. Top 10 vs. Top 20')
ax.set_xticks(index + 2*bar_width)
ax.set_xticklabels(labels, rotation=45, ha='right')
ax.legend()

# Adding horizontal line at 0
ax.axhline(0, color='gray', linewidth=0.8)

# Adding labels for the changes
for rects in [bar1, bar2, bar3, bar4, bar5]:
    for rect in rects:
        height = rect.get_height()
        if height > 0:
            ax.text(rect.get_x() + rect.get_width() / 2., height,
                    '%.3f' % height,
                    ha='center', va='bottom')
        else:
            ax.text(rect.get_x() + rect.get_width() / 2., height,
                    '%.3f' % height,
                    ha='center', va='top')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Dataset

# %%
import pandas as pd

df = pd.read_json('./Amazon/Digital_Music/Digital_Music_5.json', lines=True)
len(df)
# Out:
# 64706

# %%
df.head()
# Out:
#        reviewerID        asin          reviewerName helpful  \
# 0  A3EBHHCZO6V2A4  5555991584  Amaranth "music fan"  [3, 3]
# 1   AZPWAXJG9OJXV  5555991584             bethtexas  [0, 0]
# 2  A38IRL0X2T4DPF  5555991584           bob turnley  [2, 2]
# 3  A22IK3I6U76GX0  5555991584                 Calle  [1, 1]
# 4  A1AISPOIIHTHXX  5555991584           Cloud "..."  [1, 1]
#
#                                           reviewText  overall  \
# 0  It's hard to believe "Memory of Trees" came ou...        5
# 1  A clasically-styled and introverted album, Mem...        5
# 2  I never thought Enya would reach the sublime h...        5
# 3  This is the third review of an irish album I w...        5
# 4  Enya, despite being a successful recording art...        4
#
#                         summary  unixReviewTime   reviewTime
# 0       Enya's last great album      1158019200  09 12, 2006
# 1      Enya at her most elegant       991526400   06 3, 2001
# ...

# %%
len(df[(df['overall']>=3)])
# Out:
# 58905
